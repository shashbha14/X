# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# %%
_df = pd.read_csv(r'\Users\AIDL-LAB\Desktop\Dashan\train.csv', encoding='utf-8')
_df
_df_test = pd.read_csv(r'\Users\AIDL-LAB\Desktop\Dashan\test.csv', encoding='utf-8')

# %%
_df = pd.concat([_df,_df_test],axis=0)

# %%
_df = _df.dropna(subset=['crimeaditionalinfo'])
_df = _df.drop_duplicates()

# %%
def categorize(row):
    category_lower = row['category'].lower()

    if category_lower in ['rapegang rape rgrsexually abusive content','child pornography cpchild sexual abuse material csam','sexually obscene material','sexually explicit act','cyber bullying stalking sexting']:
        return "Women/Child Related Crime"

    elif category_lower in ['online financial fraud']:
        return "Financial Fraud Crimes"

    else:
        return "Other Cyber Crime"

_df['new_category'] = _df.apply(categorize, axis=1)
_df[['category','new_category','crimeaditionalinfo','sub_category']].sample(30)
# Out:
#                                              category  \
# 64984                          Online Financial Fraud
# 4580                           Online Financial Fraud
# 82065  Hacking  Damage to computercomputer system etc
# 27972                          Online Financial Fraud
# 2164                            Sexually Explicit Act
# 85176  Hacking  Damage to computercomputer system etc
# 87668                          Online Financial Fraud
# 51628           Online and Social Media Related Crime
# 24667       RapeGang Rape RGRSexually Abusive Content
# 3828                           Online Financial Fraud
# 16837                          Online Financial Fraud
# 75577                          Online Financial Fraud
# 85919                           Any Other Cyber Crime
# 18339                          Online Financial Fraud
# 24092  Hacking  Damage to computercomputer system etc
# 19063                          Online Financial Fraud
# 70508                       Sexually Obscene material
# 79155                          Online Financial Fraud
# 13377                          Online Financial Fraud
# 92342                          Online Financial Fraud
# 75221  Hacking  Damage to computercomputer system etc
# 54278                          Online Financial Fraud
# 8970                           Online Financial Fraud
# 84422                          Online Financial Fraud
# 3086                            Any Other Cyber Crime
# 533                             Any Other Cyber Crime
# 11937                          Online Financial Fraud
# 54468                          Online Financial Fraud
# 42603           Online and Social Media Related Crime
# 52629                       Sexually Obscene material
#
#                     new_category  \
# 64984     Financial Fraud Crimes
# 4580      Financial Fraud Crimes
# 82065          Other Cyber Crime
# 27972     Financial Fraud Crimes
# 2164   Women/Child Related Crime
# 85176          Other Cyber Crime
# 87668     Financial Fraud Crimes
# 51628          Other Cyber Crime
# 24667  Women/Child Related Crime
# 3828      Financial Fraud Crimes
# 16837     Financial Fraud Crimes
# 75577     Financial Fraud Crimes
# 85919          Other Cyber Crime
# 18339     Financial Fraud Crimes
# 24092          Other Cyber Crime
# 19063     Financial Fraud Crimes
# 70508  Women/Child Related Crime
# 79155     Financial Fraud Crimes
# 13377     Financial Fraud Crimes
# 92342     Financial Fraud Crimes
# 75221          Other Cyber Crime
# 54278     Financial Fraud Crimes
# 8970      Financial Fraud Crimes
# 84422     Financial Fraud Crimes
# 3086           Other Cyber Crime
# 533            Other Cyber Crime
# 11937     Financial Fraud Crimes
# 54468     Financial Fraud Crimes
# 42603          Other Cyber Crime
# 52629  Women/Child Related Crime
#
#                                       crimeaditionalinfo  \
# 64984  citizen details\r\n\r\nnamebadshah\r\n \r\ndis...
# 4580   Hello \r\nAccount no  Rakhi Kamlesh Bhatewara ...
# 82065  The suspect has hacked into our website and or...
# 27972  Today I received a call from No   around  PM a...
# 2164   Sir my self Arjun I face fourd For call girl I...
# 85176  By Mistake I opened suspicious fake bank mail ...
# 87668  FRAUD THROUGH  UPIPHONE PE\r\nBANK SBI BANK \r...
# 51628  I got fb frnd request then she did nude video ...
# 24667  My self Nisha Solanki\r\nI am from khurja dist...
# 3828   Caller informed that some one is called the ca...
# 16837  I got an invitation link via whatsapp about MA...
# 75577  \r\nFRAUD THROUGH   UPI  PHONE PE\r\nBANK  Pun...
# 85919  I am getting call from  from the  Rd January c...
# 18339  A call received from unknown number  called as...
# 24092  I had borrowed loan from some loan apps like h...
# 19063  FRAUD THROUGH PHONE PE UPI\r\nBANK STATE BANK ...
# 70508  Hello sir I am speaking from Tirupur  I sent  ...
# 79155  A person with the name Bablu kumar has called ...
# 13377  I asked for a Netflix subscription for a year ...
# 92342  FRAUD THROUGH GOOGLE PAY UPI\r\nBANK STATE BAN...
# 75221  I have taken certain loan from these applicati...
# 54278  Am Dr SANCHITA PRAMANICK completed MBBS in  I ...
# 8970   FRAUD THROUGH UPI PHONE PE \r\nBANK \tBANK OF ...
# 84422  She registered herself for online part time jo...
# 3086   One day I received a call from an amry persone...
# 533    I GOT MASSEGE FROM ONLINE DATING THEN I GOT CA...
# 11937  I WANT MY MONEY IS RETURN TO ME PLEASE COUGHT ...
# 54468  FRAUD THROUGH UPI Fraud GOOGLE PAY  \r\nBANK  ...
# 42603  sir this unregistered channel on face book is ...
# 52629  Im receiving this vulgar messages from past on...
#
#                                sub_category
# 64984  DebitCredit Card FraudSim Swap Fraud
# 4580                     UPI Related Frauds
# 82065             Website DefacementHacking
# 27972  DebitCredit Card FraudSim Swap Fraud
# 2164                                    NaN
# 85176                         Email Hacking
# 87668                    UPI Related Frauds
# 51628     Cyber Bullying  Stalking  Sexting
# 24667                                   NaN
# 3828   DebitCredit Card FraudSim Swap Fraud
# 16837                    UPI Related Frauds
# 75577                    UPI Related Frauds
# 85919                                 Other
# 18339        Internet Banking Related Fraud
# 24092        Unauthorised AccessData Breach
# 19063                    UPI Related Frauds
# 70508                                   NaN
# 79155                    UPI Related Frauds
# 13377                    UPI Related Frauds
# 92342                    UPI Related Frauds
# 75221        Unauthorised AccessData Breach
# 54278                    UPI Related Frauds
# 8970                     UPI Related Frauds
# 84422                    UPI Related Frauds
# 3086                                  Other
# 533                                   Other
# 11937        Internet Banking Related Fraud
# 54468                    UPI Related Frauds
# 42603     Cyber Bullying  Stalking  Sexting
# 52629                                   NaN

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\AIDL-
# [nltk_data]     LAB\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def load_custom_stopwords(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return {line.strip().lower() for line in f}

stopwords_file_path = 'C:/Users/AIDL-LAB/Desktop/Dashan/stopwords.txt'
custom_stopwords = load_custom_stopwords(stopwords_file_path)
english_stopwords = set(stopwords.words('english')).union(custom_stopwords)

_df['category'] = _df['category'].str.lower()
_df['sub_category'] = _df['sub_category'].str.lower()
_df['new_category'] = _df['new_category'].str.lower()

_df['cleaned_text'] = _df['crimeaditionalinfo'].str.lower()
_df['cleaned_text'] = _df['cleaned_text'].str.replace(r'\r\n', ' ', regex=True)
_df['cleaned_text'] = _df['cleaned_text'].str.strip()

_df['cleaned_text'] = _df['cleaned_text'].apply(
    lambda sentence: ' '.join(word for word in str(sentence).split() if word not in english_stopwords)
)

# %%
NON_ALPHANUMERIC_PATTERN = re.compile(r'[^a-zA-Z0-9\s]')
MULTIPLE_SPACES_PATTERN = re.compile(r'\s+')

def normalize_text(text):
    if not isinstance(text, str):
        return ''
    text = NON_ALPHANUMERIC_PATTERN.sub('', text)
    return MULTIPLE_SPACES_PATTERN.sub(' ', text).strip()

_df['cleaned_text'] = _df['cleaned_text'].apply(normalize_text)
_df
# Out:
#                                     category  \
# 0      online and social media related crime
# 1                     online financial fraud
# 2                   online gambling  betting
# 3      online and social media related crime
# 4                     online financial fraud
# ...                                      ...
# 31224  online and social media related crime
# 31225                 online financial fraud
# 31226                  any other cyber crime
# 31227                 online financial fraud
# 31228                  any other cyber crime
#
#                             sub_category  \
# 0      cyber bullying  stalking  sexting
# 1                      fraud callvishing
# 2               online gambling  betting
# 3                       online job fraud
# 4                      fraud callvishing
# ...                                  ...
# 31224           online matrimonial fraud
# 31225     internet banking related fraud
# 31226                              other
# 31227     internet banking related fraud
# 31228                              other
#
#                                       crimeaditionalinfo  \
# 0      I had continue received random calls and abusi...
# 1      The above fraudster is continuously messaging ...
# 2      He is acting like a police and demanding for m...
# 3      In apna Job I have applied for job interview f...
# 4      I received a call from lady stating that she w...
# ...                                                  ...
# 31224  A lady named Rashmi probably a fake name had c...
# 31225  I am Mr Chokhe Ram  Two pers mobile number wer...
# 31226  Mai Bibekbraj maine pahle ki complain kar chuk...
# 31227  received URL link for updating KYC from mobile...
# 31228  I saw add on facebook for job placement and I ...
#
#                  new_category  \
# 0           other cyber crime
# 1      financial fraud crimes
# 2           other cyber crime
# 3           other cyber crime
# 4      financial fraud crimes
# ...                       ...
# 31224       other cyber crime
# 31225  financial fraud crimes
# 31226       other cyber crime
# 31227  financial fraud crimes
# 31228       other cyber crime
#
#                                             cleaned_text
# 0      continue received random calls abusive message...
# 1      fraudster continuously messaging asking pay mo...
# 2      acting police demanding money adding sections ...
# 3      job applied job interview telecalling resource...
# 4      received call lady stating send new phone vivo...
# ...                                                  ...
# 31224  lady named rashmi probably fake name called da...
# 31225  mr chokhe ram two pers mobile number found goo...
# 31226  mai bibekbraj maine pahle ki complain kar chuk...
# 31227  received url link updating kyc mobile opening ...
# 31228  saw add facebook job placement want job contac...
#
# [113976 rows x 5 columns]

# %%
df_occ = _df[_df['new_category'] == 'other cyber crime']

# %%
df_occ.loc[df_occ['sub_category'] == 'against interest of sovereignty or integrity of india', 'sub_category'] = 'other'
df_occ.loc[df_occ['sub_category'] == 'computer generated csam/csem', 'sub_category'] = 'other'
df_occ.loc[df_occ['sub_category'] == 'cyber blackmailing & threatening', 'sub_category'] = 'other'
df_occ.loc[df_occ['sub_category'] == 'sexual harassment', 'sub_category'] = 'other'

# %%
df_occ
# Out:
#                                     category  \
# 0      online and social media related crime
# 2                   online gambling  betting
# 3      online and social media related crime
# 9                      any other cyber crime
# 10     online and social media related crime
# ...                                      ...
# 31219  online and social media related crime
# 31223  online and social media related crime
# 31224  online and social media related crime
# 31226                  any other cyber crime
# 31228                  any other cyber crime
#
#                             sub_category  \
# 0      cyber bullying  stalking  sexting
# 2               online gambling  betting
# 3                       online job fraud
# 9                                  other
# 10     cyber bullying  stalking  sexting
# ...                                  ...
# 31219          cheating by impersonation
# 31223          fakeimpersonating profile
# 31224           online matrimonial fraud
# 31226                              other
# 31228                              other
#
#                                       crimeaditionalinfo       new_category  \
# 0      I had continue received random calls and abusi...  other cyber crime
# 2      He is acting like a police and demanding for m...  other cyber crime
# 3      In apna Job I have applied for job interview f...  other cyber crime
# 9      Details entered in pdf file Person posing as A...  other cyber crime
# 10     I received a Whatsapp number in Happn Dating a...  other cyber crime
# ...                                                  ...                ...
# 31219  A fake account was createdThere were sending f...  other cyber crime
# 31223  Doing abusing messages to my friends \r\nCreat...  other cyber crime
# 31224  A lady named Rashmi probably a fake name had c...  other cyber crime
# 31226  Mai Bibekbraj maine pahle ki complain kar chuk...  other cyber crime
# 31228  I saw add on facebook for job placement and I ...  other cyber crime
#
#                                             cleaned_text
# 0      continue received random calls abusive message...
# 2      acting police demanding money adding sections ...
# 3      job applied job interview telecalling resource...
# 9      details entered pdf file person posing army of...
# 10     received whatsapp number happn dating app text...
# ...                                                  ...
# 31219  fake account createdthere sending friends requ...
# 31223  abusing messages friends creating nonsense reg...
# 31224  lady named rashmi probably fake name called da...
# 31226  mai bibekbraj maine pahle ki complain kar chuk...
# 31228  saw add facebook job placement want job contac...
#
# [39541 rows x 5 columns]

# %%
def resample_data(df, undersample_threshold=6000, oversample_threshold=2700):

    resampled_dfs = []  

 
    counts = df_occ['sub_category'].value_counts()

    for sub_cat, count in counts.items():
        sub_cat_data = df_occ[df_occ['sub_category'] == sub_cat]

        if count > undersample_threshold:
            undersampled_data = sub_cat_data.sample(undersample_threshold, random_state=42)
            resampled_dfs.append(undersampled_data)
        elif count < oversample_threshold:
            oversampled_data = sub_cat_data.sample(oversample_threshold, replace=True, random_state=42)
            resampled_dfs.append(oversampled_data)
        else:
            resampled_dfs.append(sub_cat_data)

    balanced_df = pd.concat(resampled_dfs, ignore_index=True)
    return balanced_df

balanced_df = resample_data(df_occ)
df_occ = balanced_df

# %%
df_occ.loc[:, 'label'] = df_occ['sub_category'].astype('category').cat.codes
df_occ.groupby('sub_category').describe()
# Out:
#                                                      label                   \
#                                                      count  mean  std   min
# sub_category
# cheating by impersonation                           2700.0   0.0  0.0   0.0
# cryptocurrency fraud                                2700.0   1.0  0.0   1.0
# cyber bullying  stalking  sexting                   5394.0   2.0  0.0   2.0
# cyber terrorism                                     2700.0   3.0  0.0   3.0
# damage to computer computer systems etc             2700.0   4.0  0.0   4.0
# data breach/theft                                   2700.0   5.0  0.0   5.0
# denial of service (dos)/distributed denial of s...  2700.0   6.0  0.0   6.0
# email hacking                                       2700.0   7.0  0.0   7.0
# email phishing                                      2700.0   8.0  0.0   8.0
# fakeimpersonating profile                           3046.0   9.0  0.0   9.0
# hacking/defacement                                  2700.0  10.0  0.0  10.0
# impersonating email                                 2700.0  11.0  0.0  11.0
# intimidating email                                  2700.0  12.0  0.0  12.0
# malware attack                                      2700.0  13.0  0.0  13.0
# online gambling  betting                            2700.0  14.0  0.0  14.0
# online job fraud                                    2700.0  15.0  0.0  15.0
# online matrimonial fraud                            2700.0  16.0  0.0  16.0
# online trafficking                                  2700.0  17.0  0.0  17.0
# other                                               6000.0  18.0  0.0  18.0
# profile hacking identity theft                      2819.0  19.0  0.0  19.0
# provocative speech for unlawful acts                2700.0  20.0  0.0  20.0
# ransomware                                          2700.0  21.0  0.0  21.0
# ransomware attack                                   2700.0  22.0  0.0  22.0
# sql injection                                       2700.0  23.0  0.0  23.0
# tampering with computer source documents            2700.0  24.0  0.0  24.0
# unauthorised accessdata breach                      2700.0  25.0  0.0  25.0
# website defacementhacking                           2700.0  26.0  0.0  26.0
#
#
#                                                      25%   50%   75%   max
# sub_category
# cheating by impersonation                            0.0   0.0   0.0   0.0
# cryptocurrency fraud                                 1.0   1.0   1.0   1.0
# cyber bullying  stalking  sexting                    2.0   2.0   2.0   2.0
# cyber terrorism                                      3.0   3.0   3.0   3.0
# damage to computer computer systems etc              4.0   4.0   4.0   4.0
# data breach/theft                                    5.0   5.0   5.0   5.0
# denial of service (dos)/distributed denial of s...   6.0   6.0   6.0   6.0
# email hacking                                        7.0   7.0   7.0   7.0
# email phishing                                       8.0   8.0   8.0   8.0
# fakeimpersonating profile                            9.0   9.0   9.0   9.0
# hacking/defacement                                  10.0  10.0  10.0  10.0
# impersonating email                                 11.0  11.0  11.0  11.0
# intimidating email                                  12.0  12.0  12.0  12.0
# malware attack                                      13.0  13.0  13.0  13.0
# online gambling  betting                            14.0  14.0  14.0  14.0
# online job fraud                                    15.0  15.0  15.0  15.0
# online matrimonial fraud                            16.0  16.0  16.0  16.0
# online trafficking                                  17.0  17.0  17.0  17.0
# other                                               18.0  18.0  18.0  18.0
# profile hacking identity theft                      19.0  19.0  19.0  19.0
# provocative speech for unlawful acts                20.0  20.0  20.0  20.0
# ransomware                                          21.0  21.0  21.0  21.0
# ransomware attack                                   22.0  22.0  22.0  22.0
# sql injection                                       23.0  23.0  23.0  23.0
# tampering with computer source documents            24.0  24.0  24.0  24.0
# unauthorised accessdata breach                      25.0  25.0  25.0  25.0
# website defacementhacking                           26.0  26.0  26.0  26.0

# %%
texts = df_occ['cleaned_text'].tolist() 
labels = df_occ['label'].tolist()

# %%
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import numpy as np
from torch.optim import AdamW as TorchAdamW 
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import torch.nn.functional as F

# %%
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            truncation=True,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=len(df_occ['label'].unique()))
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
MAX_LEN = 256
BATCH_SIZE = 16
LEARNING_RATE = 2e-5
EPOCHS = 7

# %%
texts = df_occ['cleaned_text'].tolist() 
labels = df_occ['label'].tolist()
from torch.optim import AdamW

# %%
train_texts, val_texts, train_labels, val_labels = train_test_split(
    texts, labels, test_size=0.2, random_state=42
)

train_dataset = TextDataset(train_texts, train_labels, tokenizer, MAX_LEN)
val_dataset  = TextDataset(val_texts, val_labels, tokenizer, MAX_LEN)


train_loader = DataLoader(train_dataset, sampler=RandomSampler(train_dataset), batch_size=BATCH_SIZE)
val_loader = DataLoader(val_dataset, sampler=SequentialSampler(val_dataset), batch_size=BATCH_SIZE)


optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=0.01)
total_steps = len(train_loader) * EPOCHS
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=int(0.1 * total_steps), num_training_steps=total_steps)

# %%
def train_epoch(model, data_loader, optimizer, scheduler, device):
    model.train()
    losses = []
    correct_predictions = 0

    for batch in tqdm(data_loader, desc="Training"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        logits = outputs.logits

        _, preds = torch.max(logits, dim=1)
        correct_predictions += torch.sum(preds == labels)
        losses.append(loss.item())

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()
        optimizer.zero_grad()

    accuracy = correct_predictions.double() / len(data_loader.dataset)
    average_loss = np.mean(losses)

    return {'accuracy': accuracy, 'loss': average_loss}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
device
# Out:
# device(type='cuda')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_model(model, data_loader, device):
    model.eval()
    predictions, true_labels = [], []
    total_loss = 0

    with torch.no_grad():
        for batch in tqdm(data_loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            logits = outputs.logits

            loss = F.cross_entropy(logits, labels)
            total_loss += loss.item()

            _, preds = torch.max(logits, dim=1)
            predictions.extend(preds.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / len(data_loader)

    accuracy = accuracy_score(true_labels, predictions)
    precision = precision_score(true_labels, predictions, average='weighted')
    recall = recall_score(true_labels, predictions, average='weighted')
    f1 = f1_score(true_labels, predictions, average='weighted')

    print("Evaluation Metrics:")
    print(f"Loss: {avg_loss:.4f}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

    return {
        'loss': avg_loss,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    }

# %%
best_accuracy = 0

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch + 1}/{EPOCHS}")
 
    train_metrics = train_epoch(model, train_loader, optimizer, scheduler, device)
    train_loss = train_metrics['loss']
    train_accuracy = train_metrics['accuracy']
   
    val_metrics = evaluate_model(model, val_loader, device)
    val_loss = val_metrics['loss']
    val_accuracy = val_metrics['accuracy']
    val_f1 = val_metrics['f1_score']
    val_precision =val_metrics['precision']
    val_recall = val_metrics['recall']
    print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")
    print(f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}, Val F1 Score: {val_f1:.4f} ,Val Precision: {val_precision:.4f}, Val recall: {val_recall: .4f}")

    if val_accuracy > best_accuracy:
        torch.save(model.state_dict(), 'best_model_state_ffc.bin')
        best_accuracy = val_accuracy

print("Training complete.")
# Out:
# Epoch 1/7
# Training: 100%|██████████| 3968/3968 [34:16<00:00,  1.93it/s]
# Evaluating: 100%|██████████| 992/992 [03:11<00:00,  5.19it/s]
# c:\Users\AIDL-LAB\Desktop\Dashan\venv1\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Evaluation Metrics:
# Loss: 1.2631
# Accuracy: 0.5573
# Precision: 0.5219
# Recall: 0.5573
# F1 Score: 0.5197
# Train Loss: 2.0654, Train Accuracy: 0.3578
# Val Loss: 1.2631, Val Accuracy: 0.5573, Val F1 Score: 0.5197 ,Val Precision: 0.5219, Val recall:  0.5573
#
# Epoch 2/7
# Training: 100%|██████████| 3968/3968 [33:52<00:00,  1.95it/s]
# Evaluating: 100%|██████████| 992/992 [03:30<00:00,  4.71it/s]
# c:\Users\AIDL-LAB\Desktop\Dashan\venv1\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Evaluation Metrics:
# Loss: 0.9547
# Accuracy: 0.6402
# Precision: 0.6467
# Recall: 0.6402
# F1 Score: 0.6147
# Train Loss: 1.0713, Train Accuracy: 0.6167
# Val Loss: 0.9547, Val Accuracy: 0.6402, Val F1 Score: 0.6147 ,Val Precision: 0.6467, Val recall:  0.6402
#
# Epoch 3/7
# Training: 100%|██████████| 3968/3968 [34:01<00:00,  1.94it/s]
# Evaluating: 100%|██████████| 992/992 [15:55<00:00,  1.04it/s]
# c:\Users\AIDL-LAB\Desktop\Dashan\venv1\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Evaluation Metrics:
# Loss: 0.9030
# Accuracy: 0.6616
# Precision: 0.6653
# Recall: 0.6616
# F1 Score: 0.6336
# Train Loss: 0.8457, Train Accuracy: 0.6798
# Val Loss: 0.9030, Val Accuracy: 0.6616, Val F1 Score: 0.6336 ,Val Precision: 0.6653, Val recall:  0.6616
#
# Epoch 4/7
# Training: 100%|██████████| 3968/3968 [33:54<00:00,  1.95it/s]
# Evaluating: 100%|██████████| 992/992 [03:27<00:00,  4.77it/s]
# Evaluation Metrics:
# Loss: 0.8992
# Accuracy: 0.6736
# Precision: 0.6709
# Recall: 0.6736
# F1 Score: 0.6604
# Train Loss: 0.7340, Train Accuracy: 0.7163
# Val Loss: 0.8992, Val Accuracy: 0.6736, Val F1 Score: 0.6604 ,Val Precision: 0.6709, Val recall:  0.6736
#
# Epoch 5/7
# Training: 100%|██████████| 3968/3968 [34:04<00:00,  1.94it/s]
# Evaluating: 100%|██████████| 992/992 [03:26<00:00,  4.81it/s]
# c:\Users\AIDL-LAB\Desktop\Dashan\venv1\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Evaluation Metrics:
# Loss: 0.9535
# Accuracy: 0.6794
# Precision: 0.6656
# Recall: 0.6794
# F1 Score: 0.6624
# Train Loss: 0.6523, Train Accuracy: 0.7450
# Val Loss: 0.9535, Val Accuracy: 0.6794, Val F1 Score: 0.6624 ,Val Precision: 0.6656, Val recall:  0.6794
#
# Epoch 6/7
# Training: 100%|██████████| 3968/3968 [33:30<00:00,  1.97it/s]
# Evaluating: 100%|██████████| 992/992 [03:22<00:00,  4.89it/s]
# Evaluation Metrics:
# Loss: 0.9890
# Accuracy: 0.6795
# Precision: 0.6831
# Recall: 0.6795
# F1 Score: 0.6678
# Train Loss: 0.5931, Train Accuracy: 0.7648
# Val Loss: 0.9890, Val Accuracy: 0.6795, Val F1 Score: 0.6678 ,Val Precision: 0.6831, Val recall:  0.6795
#
# Epoch 7/7
# Training: 100%|██████████| 3968/3968 [33:51<00:00,  1.95it/s]
# Evaluating: 100%|██████████| 992/992 [03:33<00:00,  4.64it/s]
# Evaluation Metrics:
# Loss: 1.0078
# Accuracy: 0.6872
# Precision: 0.6854
# Recall: 0.6872
# F1 Score: 0.6835
# Train Loss: 0.5484, Train Accuracy: 0.7828
# Val Loss: 1.0078, Val Accuracy: 0.6872, Val F1 Score: 0.6835 ,Val Precision: 0.6854, Val recall:  0.6872
# Training complete.

# %%
from huggingface_hub import login
login(token = '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')
model.push_to_hub('Darshankochar022/cyberguard_BERT_Other_Cyber_Crime')
# Out:
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Darshankochar022/cyberguard_BERT_Other_Cyber_Crime/commit/94736d7f6ee44ea56cdf0ca10134bdce41e36a7a', commit_message='Upload BertForSequenceClassification', commit_description='', oid='94736d7f6ee44ea56cdf0ca10134bdce41e36a7a', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Darshankochar022/cyberguard_BERT_Other_Cyber_Crime', endpoint='https://huggingface.co', repo_type='model', repo_id='Darshankochar022/cyberguard_BERT_Other_Cyber_Crime'), pr_revision=None, pr_num=None)

# %%
df_occ = _df[_df['new_category'] == 'other cyber crime']

# %%
df_occ.loc[df_occ['sub_category'] == 'against interest of sovereignty or integrity of india', 'sub_category'] = 'other'
df_occ.loc[df_occ['sub_category'] == 'computer generated csam/csem', 'sub_category'] = 'other'
df_occ.loc[df_occ['sub_category'] == 'cyber blackmailing & threatening', 'sub_category'] = 'other'
df_occ.loc[df_occ['sub_category'] == 'sexual harassment', 'sub_category'] = 'other'

# %%
df_occ.groupby('sub_category').size()
# Out:
# sub_category
# cheating by impersonation                                                2693
# cryptocurrency fraud                                                      631
# cyber bullying  stalking  sexting                                        5394
# cyber terrorism                                                           213
# damage to computer computer systems etc                                   146
# data breach/theft                                                         655
# denial of service (dos)/distributed denial of service (ddos) attacks      691
# email hacking                                                             479
# email phishing                                                            211
# fakeimpersonating profile                                                3046
# hacking/defacement                                                        740
# impersonating email                                                        57
# intimidating email                                                         40
# malware attack                                                            691
# online gambling  betting                                                  578
# online job fraud                                                         1203
# online matrimonial fraud                                                  170
# online trafficking                                                        244
# other                                                                   14459
# profile hacking identity theft                                           2819
# provocative speech for unlawful acts                                      541
# ransomware                                                                 74
# ransomware attack                                                         720
# sql injection                                                             675
# tampering with computer source documents                                  761
# unauthorised accessdata breach                                           1482
# website defacementhacking                                                 128
# dtype: int64

# %%
_df
# Out:
#                                     category  \
# 0      online and social media related crime
# 1                     online financial fraud
# 2                   online gambling  betting
# 3      online and social media related crime
# 4                     online financial fraud
# ...                                      ...
# 31224  online and social media related crime
# 31225                 online financial fraud
# 31226                  any other cyber crime
# 31227                 online financial fraud
# 31228                  any other cyber crime
#
#                             sub_category  \
# 0      cyber bullying  stalking  sexting
# 1                      fraud callvishing
# 2               online gambling  betting
# 3                       online job fraud
# 4                      fraud callvishing
# ...                                  ...
# 31224           online matrimonial fraud
# 31225     internet banking related fraud
# 31226                              other
# 31227     internet banking related fraud
# 31228                              other
#
#                                       crimeaditionalinfo  \
# 0      I had continue received random calls and abusi...
# 1      The above fraudster is continuously messaging ...
# 2      He is acting like a police and demanding for m...
# 3      In apna Job I have applied for job interview f...
# 4      I received a call from lady stating that she w...
# ...                                                  ...
# 31224  A lady named Rashmi probably a fake name had c...
# 31225  I am Mr Chokhe Ram  Two pers mobile number wer...
# 31226  Mai Bibekbraj maine pahle ki complain kar chuk...
# 31227  received URL link for updating KYC from mobile...
# 31228  I saw add on facebook for job placement and I ...
#
#                  new_category  \
# 0           other cyber crime
# 1      financial fraud crimes
# 2           other cyber crime
# 3           other cyber crime
# 4      financial fraud crimes
# ...                       ...
# 31224       other cyber crime
# 31225  financial fraud crimes
# 31226       other cyber crime
# 31227  financial fraud crimes
# 31228       other cyber crime
#
#                                             cleaned_text
# 0      continue received random calls abusive message...
# 1      fraudster continuously messaging asking pay mo...
# 2      acting police demanding money adding sections ...
# 3      job applied job interview telecalling resource...
# 4      received call lady stating send new phone vivo...
# ...                                                  ...
# 31224  lady named rashmi probably fake name called da...
# 31225  mr chokhe ram two pers mobile number found goo...
# 31226  mai bibekbraj maine pahle ki complain kar chuk...
# 31227  received url link updating kyc mobile opening ...
# 31228  saw add facebook job placement want job contac...
#
# [113976 rows x 5 columns]

# %%
def resample_data(df, undersample_threshold=6000, oversample_threshold=2700):

    resampled_dfs = []  

 
    counts = df_occ['sub_category'].value_counts()

    for sub_cat, count in counts.items():
        sub_cat_data = df_occ[df_occ['sub_category'] == sub_cat]

        if count > undersample_threshold:
            undersampled_data = sub_cat_data.sample(undersample_threshold, random_state=42)
            resampled_dfs.append(undersampled_data)
        elif count < oversample_threshold:
            oversampled_data = sub_cat_data.sample(oversample_threshold, replace=True, random_state=42)
            resampled_dfs.append(oversampled_data)
        else:
            resampled_dfs.append(sub_cat_data)

    balanced_df = pd.concat(resampled_dfs, ignore_index=True)
    return balanced_df

balanced_df = resample_data(df_occ)
df_occ = balanced_df

# %%
df_occ.loc[:, 'label'] = df_occ['sub_category'].astype('category').cat.codes
df_occ.groupby('sub_category').describe()
# Out:
#                                                      label                   \
#                                                      count  mean  std   min
# sub_category
# cheating by impersonation                           2700.0   0.0  0.0   0.0
# cryptocurrency fraud                                2700.0   1.0  0.0   1.0
# cyber bullying  stalking  sexting                   5394.0   2.0  0.0   2.0
# cyber terrorism                                     2700.0   3.0  0.0   3.0
# damage to computer computer systems etc             2700.0   4.0  0.0   4.0
# data breach/theft                                   2700.0   5.0  0.0   5.0
# denial of service (dos)/distributed denial of s...  2700.0   6.0  0.0   6.0
# email hacking                                       2700.0   7.0  0.0   7.0
# email phishing                                      2700.0   8.0  0.0   8.0
# fakeimpersonating profile                           3046.0   9.0  0.0   9.0
# hacking/defacement                                  2700.0  10.0  0.0  10.0
# impersonating email                                 2700.0  11.0  0.0  11.0
# intimidating email                                  2700.0  12.0  0.0  12.0
# malware attack                                      2700.0  13.0  0.0  13.0
# online gambling  betting                            2700.0  14.0  0.0  14.0
# online job fraud                                    2700.0  15.0  0.0  15.0
# online matrimonial fraud                            2700.0  16.0  0.0  16.0
# online trafficking                                  2700.0  17.0  0.0  17.0
# other                                               5600.0  18.0  0.0  18.0
# profile hacking identity theft                      2819.0  19.0  0.0  19.0
# provocative speech for unlawful acts                2700.0  20.0  0.0  20.0
# ransomware                                          2700.0  21.0  0.0  21.0
# ransomware attack                                   2700.0  22.0  0.0  22.0
# sql injection                                       2700.0  23.0  0.0  23.0
# tampering with computer source documents            2700.0  24.0  0.0  24.0
# unauthorised accessdata breach                      2700.0  25.0  0.0  25.0
# website defacementhacking                           2700.0  26.0  0.0  26.0
#
#
#                                                      25%   50%   75%   max
# sub_category
# cheating by impersonation                            0.0   0.0   0.0   0.0
# cryptocurrency fraud                                 1.0   1.0   1.0   1.0
# cyber bullying  stalking  sexting                    2.0   2.0   2.0   2.0
# cyber terrorism                                      3.0   3.0   3.0   3.0
# damage to computer computer systems etc              4.0   4.0   4.0   4.0
# data breach/theft                                    5.0   5.0   5.0   5.0
# denial of service (dos)/distributed denial of s...   6.0   6.0   6.0   6.0
# email hacking                                        7.0   7.0   7.0   7.0
# email phishing                                       8.0   8.0   8.0   8.0
# fakeimpersonating profile                            9.0   9.0   9.0   9.0
# hacking/defacement                                  10.0  10.0  10.0  10.0
# impersonating email                                 11.0  11.0  11.0  11.0
# intimidating email                                  12.0  12.0  12.0  12.0
# malware attack                                      13.0  13.0  13.0  13.0
# online gambling  betting                            14.0  14.0  14.0  14.0
# online job fraud                                    15.0  15.0  15.0  15.0
# online matrimonial fraud                            16.0  16.0  16.0  16.0
# online trafficking                                  17.0  17.0  17.0  17.0
# other                                               18.0  18.0  18.0  18.0
# profile hacking identity theft                      19.0  19.0  19.0  19.0
# provocative speech for unlawful acts                20.0  20.0  20.0  20.0
# ransomware                                          21.0  21.0  21.0  21.0
# ransomware attack                                   22.0  22.0  22.0  22.0
# sql injection                                       23.0  23.0  23.0  23.0
# tampering with computer source documents            24.0  24.0  24.0  24.0
# unauthorised accessdata breach                      25.0  25.0  25.0  25.0
# website defacementhacking                           26.0  26.0  26.0  26.0

# %%
texts = df_occ['cleaned_text'].tolist() 
labels = df_occ['label'].tolist()

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=len(df_occ['label'].unique()))
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
device
# Out:
# device(type='cuda')

# %%
train_texts, val_texts, train_labels, val_labels = train_test_split(
    texts, labels, test_size=0.25, random_state=42
)

train_dataset = TextDataset(train_texts, train_labels, tokenizer, MAX_LEN)
val_dataset  = TextDataset(val_texts, val_labels, tokenizer, MAX_LEN)

train_loader = DataLoader(train_dataset, sampler=RandomSampler(train_dataset), batch_size=BATCH_SIZE)
val_loader = DataLoader(val_dataset, sampler=SequentialSampler(val_dataset), batch_size=BATCH_SIZE)

optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=0.01)
total_steps = len(train_loader) * EPOCHS
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=int(0.1 * total_steps), num_training_steps=total_steps)

# %%
def train_epoch(model, data_loader, optimizer, scheduler, device):
    model.train()
    losses = []
    correct_predictions = 0

    for batch in tqdm(data_loader, desc="Training"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        logits = outputs.logits

        _, preds = torch.max(logits, dim=1)
        correct_predictions += torch.sum(preds == labels)
        losses.append(loss.item())

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()
        optimizer.zero_grad()

    accuracy = correct_predictions.double() / len(data_loader.dataset)
    average_loss = np.mean(losses)

    return {'accuracy': accuracy, 'loss': average_loss}

# %%
best_accuracy = 0

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch + 1}/{EPOCHS}")
 
    train_metrics = train_epoch(model, train_loader, optimizer, scheduler, device)
    train_loss = train_metrics['loss']
    train_accuracy = train_metrics['accuracy']
   
    val_metrics = evaluate_model(model, val_loader, device)
    val_loss = val_metrics['loss']
    val_accuracy = val_metrics['accuracy']
    val_f1 = val_metrics['f1_score']
    val_precision =val_metrics['precision']
    val_recall = val_metrics['recall']
    print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")
    print(f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}, Val F1 Score: {val_f1:.4f} ,Val Precision: {val_precision:.4f}, Val recall: {val_recall: .4f}")

    if val_accuracy > best_accuracy:
        torch.save(model.state_dict(), 'occ.bin')
        best_accuracy = val_accuracy

print("Training complete.")
# Out:
# Epoch 1/7
# Training:   1%|          | 44/3702 [00:22<30:44,  1.98it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 6
#       3 for epoch in range(EPOCHS):
#       4     print(f"\nEpoch {epoch + 1}/{EPOCHS}")
# ----> 6     train_metrics = train_epoch(model, train_loader, optimizer, scheduler, device)
#       7     train_loss = train_metrics['loss']
#       8     train_accuracy = train_metrics['accuracy']
#
# Cell In[89], line 6, in train_epoch(model, data_loader, optimizer, scheduler, device)
#       3 losses = []
#       4 correct_predictions = 0
# ----> 6 for batch in tqdm(data_loader, desc="Training"):
#       7     input_ids = batch['input_ids'].to(device)
#       8     attention_mask = batch['attention_mask'].to(device)
#
# File c:\Users\AIDL-LAB\Desktop\Dashan\venv1\lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\AIDL-LAB\Desktop\Dashan\venv1\lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\Users\AIDL-LAB\Desktop\Dashan\venv1\lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\AIDL-LAB\Desktop\Dashan\venv1\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\Users\AIDL-LAB\Desktop\Dashan\venv1\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[19], line 24, in TextDataset.__getitem__(self, idx)
#      13 label = self.labels[idx]
#      14 encoding = self.tokenizer.encode_plus(
#      15     text,
#      16     add_special_tokens=True,
#    (...)
#      21     return_tensors='pt'
#      22 )
#      23 return {
# ---> 24     'input_ids': encoding['input_ids'].flatten(),
#      25     'attention_mask': encoding['attention_mask'].flatten(),
#      26     'labels': torch.tensor(label, dtype=torch.long)
#      27 }
#
# KeyboardInterrupt:

# %%
model.push_to_hub('Darshankochar022/cyberguard_BERT_Other_Cyber_Crimes')
# Out:
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Darshankochar022/cyberguard_BERT_Other_Cyber_Crimes/commit/6d6b49fb494cd095167c0d58f03290f646c0ecbc', commit_message='Upload BertForSequenceClassification', commit_description='', oid='6d6b49fb494cd095167c0d58f03290f646c0ecbc', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Darshankochar022/cyberguard_BERT_Other_Cyber_Crimes', endpoint='https://huggingface.co', repo_type='model', repo_id='Darshankochar022/cyberguard_BERT_Other_Cyber_Crimes'), pr_revision=None, pr_num=None)
